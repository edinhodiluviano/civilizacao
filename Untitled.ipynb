# %%
from random import randint
from typing import Any, Self
from dataclasses import asdict, dataclass

# %%
import pandas as pd
import holoviews as hv
hv.extension('bokeh')
# Out:
# %opts magic unavailable (pyparsing cannot be imported)
# %compositor magic unavailable (pyparsing cannot be imported)
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='f6efdece-84f5-4ba8-a949-679aeebbd36d'>
#   <div id="b2c89599-8f5e-4e8a-8289-24e3e9b01a75" data-root-id="f6efdece-84f5-4ba8-a949-679aeebbd36d" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"40eea1a5-58c9-4ff1-a2e0-61ebc2ae579d":{"version":"3.6.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"f6efdece-84f5-4ba8-a949-679aeebbd36d"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"479bce3a-7893-45b4-9034-2248b18b411e","attributes":{"plot_id":"f6efdece-84f5-4ba8-a949-679aeebbd36d","comm_id":"e02ab9e2185642828257b287cb63d16a","client_comm_id":"6955c946c2e946449a44155516871f8f"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","d ...
#   var render_items = [{"docid":"40eea1a5-58c9-4ff1-a2e0-61ebc2ae579d","roots":{"f6efdece-84f5-4ba8-a949-679aeebbd36d":"b2c89599-8f5e-4e8a-8289-24e3e9b01a75"},"root_ids":["f6efdece-84f5-4ba8-a949-679aeebbd36d"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %%
class Acao:
    def __init__(self, val: str) -> None:
        self.val = val

    def __bool__(self) -> bool:
        return self.val == 'C'

    def __repr__(self) -> str:
        return self.val

    def reverter(self) -> Self:
        return self.__class__('T') if self.val == 'C' else self.__class__('C')

    def __eq__(self, other: Any) -> bool:
        return isinstance(other, self.__class__) and self.val == other.val


T = Acao('T')
C = Acao('C')

# %%
def houver(nivel: int) -> int:
    return nivel > randint(0, 99)

# %%
def payoff(p1, p2) -> tuple[int, int]:
    match bool(p1), bool(p2):
        case True, True:
            return 3, 3
        case True, False:
            return 0, 5
        case False, True:
            return 5, 0
        case False, False:
            return 1, 1

# %%
@dataclass
class Turno:
    a1: Acao
    a2: Acao
    r1: int
    r2: int

    @classmethod
    def from_acao(cls, a1: Acao, a2: Acao) -> Self:
        r1, r2 = payoff(a1, a2)
        o = cls(a1=a1, a2=a2, r1=r1, r2=r2)
        return o

    def __repr__(self) -> str:
        a1, a2 = self.a1, self.a2
        r1, r2 = self.r1, self.r2
        m = f'{a1}  {a2}  |  {r1: 2}  {r2: 2}'
        return m

    def reverter(self) -> Self:
        return self.__class__(a1=self.a2, a2=self.a1, r1=self.r2, r2=self.r1)

# %%
def aplicar_ruido(ruido: int, acao: Acao) -> Acao:
    return acao.reverter() if houver(ruido) else acao

# %%
@dataclass
class Estrategia:
    malandragem: int = 0
    justica: int = 0
    castigo: int = 0
    perdao: int = 0
    pontos: int = 0

    def __post_init__(self) -> None:
        self._castigo = 0

    def __repr__(self) -> str:
        s = ', '.join(
            (f'{k}={v:3}' if k != 'pontos' else f'{k}={v:6}')
            for k, v
            in asdict(self).items()
        )
        return f'Estrategia({s})'

    def __str__(self) -> str:
        return self.__repr__()

    def __mul__(self, val: int) -> list[Self]:
        return [self.__class__(**asdict(self)) for _ in range(val)]

    def jogar(self, passado: list[Turno], rev: bool, ruido: int) -> Acao:
        outra_acao = lambda p: p.a1 if rev is True else p.a2

        # justica
        if len(passado) > 0 and houver(self.justica):
            ultima_acao_real = outra_acao(passado[-1])
            ultima_acao_percebida = aplicar_ruido(ruido, ultima_acao_real)
            if bool(ultima_acao_percebida) is False:
                self._castigo = self.castigo + 1

        # perdao
        if houver(self.perdao):
            self._castigo = 0

        # castigar
        if self._castigo:
            self._castigo -= 1
            return T

        # malandragem
        return T if houver(self.malandragem) else C

# %%
def jogo(
    e1: Estrategia,
    e2: Estrategia,
    rodadas: int,
    ruido: int,
) -> tuple[Estrategia, Estrategia, str, list[Turno]]:

    turnos = []
    for n in range(rodadas):
        a1 = e1.jogar(turnos[-5:], rev=False, ruido=ruido)
        a2 = e2.jogar(turnos[-5:], rev=True, ruido=ruido)
        turno = Turno.from_acao(a1, a2)
        turnos.append(turno)
        e1.pontos += turno.r1
        e2.pontos += turno.r2

    if e1.pontos == e2.pontos:
        vencedor = 'empate'
    elif e1.pontos > e2.pontos:
        vencedor = 'e1'
    else:
        vencedor = 'e2'

    return e1, e2, vencedor, turnos

# %%
def arena(
    rodadas: int,
    estrategias: list[Estrategia],
    ruido: int = 0,
) -> list[Estrategia]:
    for pos1 in range(len(estrategias) - 1):
        for pos2 in range(pos1 + 1, len(estrategias)):
            e1 = estrategias[pos1]
            e2 = estrategias[pos2]
            e1, e2, vencedor, _ = jogo(e1=e1, e2=e2, rodadas=rodadas, ruido=ruido)
            estrategias[pos1] = e1
            estrategias[pos2] = e2
    estrategias = sorted(estrategias, key=lambda e: e.pontos, reverse=True)
    return estrategias

# %% [markdown]
# # Jogo 1: Cooperadora vs Trapaceira

# %%
Cooperadora = Estrategia(malandragem=0)
Trapaceira = Estrategia(malandragem=50)

# %%
e1, e2, _, t = jogo(Cooperadora, Trapaceira, rodadas=200, ruido=0)
df = pd.DataFrame(t)
df.head(10)
# Out:
#   a1 a2  r1  r2
# 0  C  T   0   5
# 1  C  T   0   5
# 2  C  T   0   5
# 3  C  T   0   5
# 4  C  T   0   5
# 5  C  T   0   5
# 6  C  C   3   3
# 7  C  T   0   5
# 8  C  C   3   3
# 9  C  C   3   3

# %%
def colorir(df):
    def destacar_acao(v):
        if v == C:
            return 'background-color: green'
        elif v == T:
            return 'background-color: red'
    return df.style.apply(lambda x: x.map(destacar_acao), axis=None)

colorir(df.head(10))
# Out:
# <style type="text/css">
# #T_6fee1_row0_col0, #T_6fee1_row1_col0, #T_6fee1_row2_col0, #T_6fee1_row3_col0, #T_6fee1_row4_col0, #T_6fee1_row5_col0, #T_6fee1_row6_col0, #T_6fee1_row6_col1, #T_6fee1_row7_col0, #T_6fee1_row8_col0, #T_6fee1_row8_col1, #T_6fee1_row9_col0, #T_6fee1_row9_col1 {
#   background-color: green;
# }
# #T_6fee1_row0_col1, #T_6fee1_row1_col1, #T_6fee1_row2_col1, #T_6fee1_row3_col1, #T_6fee1_row4_col1, #T_6fee1_row5_col1, #T_6fee1_row7_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_6fee1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6fee1_level0_col0" class="col_heading level0 col0" >a1</th>
#       <th id="T_6fee1_level0_col1" class="col_heading level0 col1" >a2</th>
#       <th id="T_6fee1_level0_col2" class="col_heading level0 col2" >r1</th>
#       <th id="T_6fee1_level0_col3" class="col_heading level0 col3" >r2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6fee1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6fee1_row0_col0" class="data row0 col0" >C</td>
#       <td id="T_6fee1_row0_col1" class="data row0 col1" >T</td>
#       <td id="T_6fee1_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_6fee1_row0_col3" class="data row0 col3" >5</td>
#     </tr>
#     <tr>
#       <th id="T_6fee1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6fee1_row1_col0" class="data row1 col0" >C</td>
#       <td id="T_6fee1_row1_col1" class="data row1 col1" >T</td>
#       <td id="T_6fee1_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_6fee1_row1_col3" class="data row1 col3" >5</td>
#     </tr>
#     <tr>
#       <th id="T_6fee1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6fee1_row2_col0" class="data row2 col0" >C</td>
#       <td id="T_6fee1_row2_col1" class="data row2 col1" >T</td>
#       <td id="T_6fee1_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_6fee1_row2_col3" class="data row2 col3" >5</td>
#     </tr>
#     <tr>
#       <th id="T_6fee1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6fee1_row3_col0" class="data row3 col0" >C</td>
#       <td id="T_6fee1_row3_col1" class="data row3 col1" >T</td>
#       <td id="T_6fee1_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_6fee1_row3_col3" class="data row3 col3" >5</td>
#     </tr>
#     <tr>
#       <th id="T_6fee1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6fee1_row4_col0" class="data row4 col0" >C</td>
#       <td id="T_6fee1_row4_col1" class="data row4 col1" >T</td>
#       <td id="T_6fee1_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_6fee1_row4_col3" class="data row4 col3" >5</td>
#     </tr>
#     <tr>
#       <th id="T_6fee1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6fee1_row5_col0" class="data row5 col0" >C</td>
#       <td id="T_6fee1_row5_col1" class="data row5 col1" >T</td>
#       <td id="T_6fee1_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_6fee1_row5_col3" class="data row5 col3" >5</td>
#     </tr>
#     <tr>
#       <th id="T_6fee1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6fee1_row6_col0" class="data row6 col0" >C</td>
#       <td id="T_6fee1_row6_col1" class="data row6 col1" >C</td>
#       <td id="T_6fee1_row6_col2" class="data row6 col2" >3</td>
#       <td id="T_6fee1_row6_col3" class="data row6 col3" >3</td>
#     </tr>
#     <tr>
#       <th id="T_6fee1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6fee1_row7_col0" class="data row7 col0" >C</td>
#       <td id="T_6fee1_row7_col1" class="data row7 col1" >T</td>
#       <td id="T_6fee1_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_6fee1_row7_col3" class="data row7 col3" >5</td>
#     </tr>
#     <tr>
#       <th id="T_6fee1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6fee1_row8_col0" class="data row8 col0" >C</td>
#       <td id="T_6fee1_row8_col1" class="data row8 col1" >C</td>
#       <td id="T_6fee1_row8_col2" class="data row8 col2" >3</td>
#       <td id="T_6fee1_row8_col3" class="data row8 col3" >3</td>
#     </tr>
#     <tr>
#       <th id="T_6fee1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6fee1_row9_col0" class="data row9 col0" >C</td>
#       <td id="T_6fee1_row9_col1" class="data row9 col1" >C</td>
#       <td id="T_6fee1_row9_col2" class="data row9 col2" >3</td>
#       <td id="T_6fee1_row9_col3" class="data row9 col3" >3</td>
#     </tr>
#   </tbody>
# </table>

# %%
df['r1_acc'] = df['r1'].cumsum()
df['r2_acc'] = df['r2'].cumsum()
colorir(df.head(10))
# Out:
# <style type="text/css">
# #T_0af27_row0_col0, #T_0af27_row1_col0, #T_0af27_row2_col0, #T_0af27_row3_col0, #T_0af27_row4_col0, #T_0af27_row5_col0, #T_0af27_row6_col0, #T_0af27_row6_col1, #T_0af27_row7_col0, #T_0af27_row8_col0, #T_0af27_row8_col1, #T_0af27_row9_col0, #T_0af27_row9_col1 {
#   background-color: green;
# }
# #T_0af27_row0_col1, #T_0af27_row1_col1, #T_0af27_row2_col1, #T_0af27_row3_col1, #T_0af27_row4_col1, #T_0af27_row5_col1, #T_0af27_row7_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_0af27">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0af27_level0_col0" class="col_heading level0 col0" >a1</th>
#       <th id="T_0af27_level0_col1" class="col_heading level0 col1" >a2</th>
#       <th id="T_0af27_level0_col2" class="col_heading level0 col2" >r1</th>
#       <th id="T_0af27_level0_col3" class="col_heading level0 col3" >r2</th>
#       <th id="T_0af27_level0_col4" class="col_heading level0 col4" >r1_acc</th>
#       <th id="T_0af27_level0_col5" class="col_heading level0 col5" >r2_acc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0af27_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0af27_row0_col0" class="data row0 col0" >C</td>
#       <td id="T_0af27_row0_col1" class="data row0 col1" >T</td>
#       <td id="T_0af27_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_0af27_row0_col3" class="data row0 col3" >5</td>
#       <td id="T_0af27_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_0af27_row0_col5" class="data row0 col5" >5</td>
#     </tr>
#     <tr>
#       <th id="T_0af27_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0af27_row1_col0" class="data row1 col0" >C</td>
#       <td id="T_0af27_row1_col1" class="data row1 col1" >T</td>
#       <td id="T_0af27_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_0af27_row1_col3" class="data row1 col3" >5</td>
#       <td id="T_0af27_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_0af27_row1_col5" class="data row1 col5" >10</td>
#     </tr>
#     <tr>
#       <th id="T_0af27_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0af27_row2_col0" class="data row2 col0" >C</td>
#       <td id="T_0af27_row2_col1" class="data row2 col1" >T</td>
#       <td id="T_0af27_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_0af27_row2_col3" class="data row2 col3" >5</td>
#       <td id="T_0af27_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_0af27_row2_col5" class="data row2 col5" >15</td>
#     </tr>
#     <tr>
#       <th id="T_0af27_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0af27_row3_col0" class="data row3 col0" >C</td>
#       <td id="T_0af27_row3_col1" class="data row3 col1" >T</td>
#       <td id="T_0af27_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_0af27_row3_col3" class="data row3 col3" >5</td>
#       <td id="T_0af27_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_0af27_row3_col5" class="data row3 col5" >20</td>
#     </tr>
#     <tr>
#       <th id="T_0af27_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0af27_row4_col0" class="data row4 col0" >C</td>
#       <td id="T_0af27_row4_col1" class="data row4 col1" >T</td>
#       <td id="T_0af27_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_0af27_row4_col3" class="data row4 col3" >5</td>
#       <td id="T_0af27_row4_col4" class="data row4 col4" >0</td>
#       <td id="T_0af27_row4_col5" class="data row4 col5" >25</td>
#     </tr>
#     <tr>
#       <th id="T_0af27_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0af27_row5_col0" class="data row5 col0" >C</td>
#       <td id="T_0af27_row5_col1" class="data row5 col1" >T</td>
#       <td id="T_0af27_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_0af27_row5_col3" class="data row5 col3" >5</td>
#       <td id="T_0af27_row5_col4" class="data row5 col4" >0</td>
#       <td id="T_0af27_row5_col5" class="data row5 col5" >30</td>
#     </tr>
#     <tr>
#       <th id="T_0af27_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0af27_row6_col0" class="data row6 col0" >C</td>
#       <td id="T_0af27_row6_col1" class="data row6 col1" >C</td>
#       <td id="T_0af27_row6_col2" class="data row6 col2" >3</td>
#       <td id="T_0af27_row6_col3" class="data row6 col3" >3</td>
#       <td id="T_0af27_row6_col4" class="data row6 col4" >3</td>
#       <td id="T_0af27_row6_col5" class="data row6 col5" >33</td>
#     </tr>
#     <tr>
#       <th id="T_0af27_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0af27_row7_col0" class="data row7 col0" >C</td>
#       <td id="T_0af27_row7_col1" class="data row7 col1" >T</td>
#       <td id="T_0af27_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_0af27_row7_col3" class="data row7 col3" >5</td>
#       <td id="T_0af27_row7_col4" class="data row7 col4" >3</td>
#       <td id="T_0af27_row7_col5" class="data row7 col5" >38</td>
#     </tr>
#     <tr>
#       <th id="T_0af27_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0af27_row8_col0" class="data row8 col0" >C</td>
#       <td id="T_0af27_row8_col1" class="data row8 col1" >C</td>
#       <td id="T_0af27_row8_col2" class="data row8 col2" >3</td>
#       <td id="T_0af27_row8_col3" class="data row8 col3" >3</td>
#       <td id="T_0af27_row8_col4" class="data row8 col4" >6</td>
#       <td id="T_0af27_row8_col5" class="data row8 col5" >41</td>
#     </tr>
#     <tr>
#       <th id="T_0af27_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0af27_row9_col0" class="data row9 col0" >C</td>
#       <td id="T_0af27_row9_col1" class="data row9 col1" >C</td>
#       <td id="T_0af27_row9_col2" class="data row9 col2" >3</td>
#       <td id="T_0af27_row9_col3" class="data row9 col3" >3</td>
#       <td id="T_0af27_row9_col4" class="data row9 col4" >9</td>
#       <td id="T_0af27_row9_col5" class="data row9 col5" >44</td>
#     </tr>
#   </tbody>
# </table>

# %%
opts = dict(width=500, height=400, show_grid=True)
hv.Curve(df, kdims='index', vdims='r1_acc') * hv.Curve(df, kdims='index', vdims='r2_acc').opts(**opts)
# Out:
# :Overlay
#    .Curve.I  :Curve   [index]   (r1_acc)
#    .Curve.II :Curve   [index]   (r2_acc)

# %% [markdown]
# # Jogo 2: O mundo com várias pessoas

# %%
e = (
    Cooperadora * 5
    + Trapaceira * 5
)

for i in arena(rodadas=200, estrategias=e): print(i);
# Out:
# Estrategia(malandragem= 50, justica=  0, castigo=  0, perdao=  0, pontos=  6722)
# Estrategia(malandragem= 50, justica=  0, castigo=  0, perdao=  0, pontos=  6703)
# Estrategia(malandragem= 50, justica=  0, castigo=  0, perdao=  0, pontos=  6575)
# Estrategia(malandragem= 50, justica=  0, castigo=  0, perdao=  0, pontos=  6574)
# Estrategia(malandragem= 50, justica=  0, castigo=  0, perdao=  0, pontos=  6463)
# Estrategia(malandragem=  0, justica=  0, castigo=  0, perdao=  0, pontos=  4257)
# Estrategia(malandragem=  0, justica=  0, castigo=  0, perdao=  0, pontos=  4245)
# Estrategia(malandragem=  0, justica=  0, castigo=  0, perdao=  0, pontos=  4239)
# Estrategia(malandragem=  0, justica=  0, castigo=  0, perdao=  0, pontos=  4194)
# Estrategia(malandragem=  0, justica=  0, castigo=  0, perdao=  0, pontos=  4164)

# %% [markdown]
# # Jogo 3: A defesa contra a malandragem

# %%
Justiceira = Estrategia(malandragem=0, justica=100)
Trapaceira = Estrategia(malandragem=50, justica=0)

e = (
    Justiceira * 12
    + Trapaceira * 12
)

for i in arena(rodadas=200, estrategias=e): print(i);
# Out:
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 12067)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 12058)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 12040)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 12022)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 11999)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 11990)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 11970)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 11970)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 11960)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 11956)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 11951)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 11934)
# Estrategia(malandragem= 50, justica=  0, castigo=  0, perdao=  0, pontos= 10603)
# Estrategia(malandragem= 50, justica=  0, castigo=  0, perdao=  0, pontos= 10548)
# Estrategia(malandragem= 50, justica=  0, castigo=  0, perdao=  0, pontos= 10529)
# Estrategia(malandragem= 50, justica=  0, castigo=  0, perdao=  0, pontos= 10504)
# Estrategia(malandragem= 50, justica=  0, castigo=  0, perdao=  0, pontos= 10483)
# Estrategia(malandragem= 50, justica=  0, castigo=  0, perdao=  0, pontos= 10415)
# Estrategia(malandragem= 50, justica=  0, castigo=  0, perdao=  0, pontos= 10378)
# Estrategia(malandragem= 50, justica=  0, castigo=  0, perdao=  0, pontos= 10359)
# Estrategia(malandragem= 50, justica=  0, castigo=  0, perdao=  0, pontos= 10298)
# Estrategia(malandragem= 50, justica=  0, castigo=  0, perdao=  0, pontos= 10265)
# Estrategia(malandragem= 50, justica=  0, castigo=  0, perdao=  0, pontos= 10250)
# Estrategia(malandragem= 50, justica=  0, castigo=  0, perdao=  0, pontos= 10200)

# %%
e1, e2, _, t = jogo(Justiceira, Trapaceira, rodadas=200, ruido=0)
df = pd.DataFrame(t)
colorir(df.head(10))
# Out:
# <style type="text/css">
# #T_e96e2_row0_col0, #T_e96e2_row0_col1, #T_e96e2_row1_col0, #T_e96e2_row1_col1, #T_e96e2_row2_col0, #T_e96e2_row3_col1, #T_e96e2_row4_col0, #T_e96e2_row4_col1, #T_e96e2_row5_col0, #T_e96e2_row7_col1, #T_e96e2_row8_col0, #T_e96e2_row9_col1 {
#   background-color: green;
# }
# #T_e96e2_row2_col1, #T_e96e2_row3_col0, #T_e96e2_row5_col1, #T_e96e2_row6_col0, #T_e96e2_row6_col1, #T_e96e2_row7_col0, #T_e96e2_row8_col1, #T_e96e2_row9_col0 {
#   background-color: red;
# }
# </style>
# <table id="T_e96e2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e96e2_level0_col0" class="col_heading level0 col0" >a1</th>
#       <th id="T_e96e2_level0_col1" class="col_heading level0 col1" >a2</th>
#       <th id="T_e96e2_level0_col2" class="col_heading level0 col2" >r1</th>
#       <th id="T_e96e2_level0_col3" class="col_heading level0 col3" >r2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e96e2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e96e2_row0_col0" class="data row0 col0" >C</td>
#       <td id="T_e96e2_row0_col1" class="data row0 col1" >C</td>
#       <td id="T_e96e2_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_e96e2_row0_col3" class="data row0 col3" >3</td>
#     </tr>
#     <tr>
#       <th id="T_e96e2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e96e2_row1_col0" class="data row1 col0" >C</td>
#       <td id="T_e96e2_row1_col1" class="data row1 col1" >C</td>
#       <td id="T_e96e2_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_e96e2_row1_col3" class="data row1 col3" >3</td>
#     </tr>
#     <tr>
#       <th id="T_e96e2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e96e2_row2_col0" class="data row2 col0" >C</td>
#       <td id="T_e96e2_row2_col1" class="data row2 col1" >T</td>
#       <td id="T_e96e2_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_e96e2_row2_col3" class="data row2 col3" >5</td>
#     </tr>
#     <tr>
#       <th id="T_e96e2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e96e2_row3_col0" class="data row3 col0" >T</td>
#       <td id="T_e96e2_row3_col1" class="data row3 col1" >C</td>
#       <td id="T_e96e2_row3_col2" class="data row3 col2" >5</td>
#       <td id="T_e96e2_row3_col3" class="data row3 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e96e2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e96e2_row4_col0" class="data row4 col0" >C</td>
#       <td id="T_e96e2_row4_col1" class="data row4 col1" >C</td>
#       <td id="T_e96e2_row4_col2" class="data row4 col2" >3</td>
#       <td id="T_e96e2_row4_col3" class="data row4 col3" >3</td>
#     </tr>
#     <tr>
#       <th id="T_e96e2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e96e2_row5_col0" class="data row5 col0" >C</td>
#       <td id="T_e96e2_row5_col1" class="data row5 col1" >T</td>
#       <td id="T_e96e2_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_e96e2_row5_col3" class="data row5 col3" >5</td>
#     </tr>
#     <tr>
#       <th id="T_e96e2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e96e2_row6_col0" class="data row6 col0" >T</td>
#       <td id="T_e96e2_row6_col1" class="data row6 col1" >T</td>
#       <td id="T_e96e2_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_e96e2_row6_col3" class="data row6 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e96e2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e96e2_row7_col0" class="data row7 col0" >T</td>
#       <td id="T_e96e2_row7_col1" class="data row7 col1" >C</td>
#       <td id="T_e96e2_row7_col2" class="data row7 col2" >5</td>
#       <td id="T_e96e2_row7_col3" class="data row7 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e96e2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e96e2_row8_col0" class="data row8 col0" >C</td>
#       <td id="T_e96e2_row8_col1" class="data row8 col1" >T</td>
#       <td id="T_e96e2_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_e96e2_row8_col3" class="data row8 col3" >5</td>
#     </tr>
#     <tr>
#       <th id="T_e96e2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e96e2_row9_col0" class="data row9 col0" >T</td>
#       <td id="T_e96e2_row9_col1" class="data row9 col1" >C</td>
#       <td id="T_e96e2_row9_col2" class="data row9 col2" >5</td>
#       <td id="T_e96e2_row9_col3" class="data row9 col3" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
Justiceira = Estrategia(malandragem=0, justica=100)
JusticeiraPassaPano = Estrategia(malandragem=0, justica=50)
Trapaceira = Estrategia(malandragem=50, justica=0)

e = (
    Justiceira * 8
    + JusticeiraPassaPano * 8
    + Trapaceira * 8
)

for i in arena(rodadas=200, estrategias=e): print(i);
# Out:
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 12653)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 12629)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 12625)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 12606)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 12586)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 12540)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 12535)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 12521)
# Estrategia(malandragem=  0, justica= 50, castigo=  0, perdao=  0, pontos= 12082)
# Estrategia(malandragem=  0, justica= 50, castigo=  0, perdao=  0, pontos= 12070)
# Estrategia(malandragem=  0, justica= 50, castigo=  0, perdao=  0, pontos= 12059)
# Estrategia(malandragem=  0, justica= 50, castigo=  0, perdao=  0, pontos= 12029)
# Estrategia(malandragem=  0, justica= 50, castigo=  0, perdao=  0, pontos= 12026)
# Estrategia(malandragem=  0, justica= 50, castigo=  0, perdao=  0, pontos= 12005)
# Estrategia(malandragem=  0, justica= 50, castigo=  0, perdao=  0, pontos= 11977)
# Estrategia(malandragem=  0, justica= 50, castigo=  0, perdao=  0, pontos= 11910)
# Estrategia(malandragem= 50, justica=  0, castigo=  0, perdao=  0, pontos= 11858)
# Estrategia(malandragem= 50, justica=  0, castigo=  0, perdao=  0, pontos= 11802)
# Estrategia(malandragem= 50, justica=  0, castigo=  0, perdao=  0, pontos= 11795)
# Estrategia(malandragem= 50, justica=  0, castigo=  0, perdao=  0, pontos= 11763)
# Estrategia(malandragem= 50, justica=  0, castigo=  0, perdao=  0, pontos= 11760)
# Estrategia(malandragem= 50, justica=  0, castigo=  0, perdao=  0, pontos= 11739)
# Estrategia(malandragem= 50, justica=  0, castigo=  0, perdao=  0, pontos= 11698)
# Estrategia(malandragem= 50, justica=  0, castigo=  0, perdao=  0, pontos= 11662)

# %%
Justiceira = Estrategia(malandragem=0, justica=100)
JusticeiraPassaPano = Estrategia(malandragem=0, justica=50)
Trapaceira = Estrategia(malandragem=50, justica=0)
CidadaDeBem = Estrategia(malandragem=50, justica=50)

e = (
    Justiceira * 6
    + JusticeiraPassaPano * 6
    + Trapaceira * 6
    + CidadaDeBem * 6
)

for i in arena(rodadas=200, estrategias=e): print(i);
# Out:
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 11648)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 11614)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 11581)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 11563)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 11548)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 11511)
# Estrategia(malandragem= 50, justica=  0, castigo=  0, perdao=  0, pontos= 11101)
# Estrategia(malandragem= 50, justica=  0, castigo=  0, perdao=  0, pontos= 11036)
# Estrategia(malandragem= 50, justica=  0, castigo=  0, perdao=  0, pontos= 10975)
# Estrategia(malandragem= 50, justica=  0, castigo=  0, perdao=  0, pontos= 10935)
# Estrategia(malandragem=  0, justica= 50, castigo=  0, perdao=  0, pontos= 10933)
# Estrategia(malandragem= 50, justica=  0, castigo=  0, perdao=  0, pontos= 10922)
# Estrategia(malandragem=  0, justica= 50, castigo=  0, perdao=  0, pontos= 10904)
# Estrategia(malandragem= 50, justica= 50, castigo=  0, perdao=  0, pontos= 10898)
# Estrategia(malandragem=  0, justica= 50, castigo=  0, perdao=  0, pontos= 10896)
# Estrategia(malandragem=  0, justica= 50, castigo=  0, perdao=  0, pontos= 10866)
# Estrategia(malandragem=  0, justica= 50, castigo=  0, perdao=  0, pontos= 10857)
# Estrategia(malandragem=  0, justica= 50, castigo=  0, perdao=  0, pontos= 10795)
# Estrategia(malandragem= 50, justica= 50, castigo=  0, perdao=  0, pontos= 10795)
# Estrategia(malandragem= 50, justica=  0, castigo=  0, perdao=  0, pontos= 10791)
# Estrategia(malandragem= 50, justica= 50, castigo=  0, perdao=  0, pontos= 10763)
# Estrategia(malandragem= 50, justica= 50, castigo=  0, perdao=  0, pontos= 10691)
# Estrategia(malandragem= 50, justica= 50, castigo=  0, perdao=  0, pontos= 10682)
# Estrategia(malandragem= 50, justica= 50, castigo=  0, perdao=  0, pontos= 10581)

# %%
e = [
    Estrategia(malandragem=m, justica=j)
    for m in range(0, 70, 10)
    for j in range(0, 100, 10)
]

resultado = arena(rodadas=200, estrategias=e)
for i in resultado: print(i);
# Out:
# Estrategia(malandragem= 60, justica= 80, castigo=  0, perdao=  0, pontos= 34419)
# Estrategia(malandragem= 60, justica= 90, castigo=  0, perdao=  0, pontos= 34169)
# Estrategia(malandragem= 60, justica= 20, castigo=  0, perdao=  0, pontos= 34092)
# Estrategia(malandragem= 60, justica= 60, castigo=  0, perdao=  0, pontos= 34080)
# Estrategia(malandragem= 60, justica= 70, castigo=  0, perdao=  0, pontos= 34080)
# Estrategia(malandragem= 50, justica= 80, castigo=  0, perdao=  0, pontos= 34060)
# Estrategia(malandragem= 60, justica= 30, castigo=  0, perdao=  0, pontos= 34060)
# Estrategia(malandragem= 50, justica= 90, castigo=  0, perdao=  0, pontos= 33998)
# Estrategia(malandragem= 60, justica= 40, castigo=  0, perdao=  0, pontos= 33995)
# Estrategia(malandragem= 60, justica= 50, castigo=  0, perdao=  0, pontos= 33952)
# Estrategia(malandragem= 50, justica= 70, castigo=  0, perdao=  0, pontos= 33685)
# Estrategia(malandragem= 60, justica=  0, castigo=  0, perdao=  0, pontos= 33676)
# Estrategia(malandragem= 50, justica= 30, castigo=  0, perdao=  0, pontos= 33656)
# Estrategia(malandragem= 60, justica= 10, castigo=  0, perdao=  0, pontos= 33570)
# Estrategia(malandragem= 50, justica= 50, castigo=  0, perdao=  0, pontos= 33559)
# Estrategia(malandragem= 50, justica= 60, castigo=  0, perdao=  0, pontos= 33441)
# Estrategia(malandragem= 50, justica= 20, castigo=  0, perdao=  0, pontos= 33407)
# Estrategia(malandragem= 40, justica= 80, castigo=  0, perdao=  0, pontos= 33379)
# Estrategia(malandragem= 40, justica= 70, castigo=  0, perdao=  0, pontos= 33375)
# Estrategia(malandragem= 50, justica= 40, castigo=  0, perdao=  0, pontos= 33356)
# Estrategia(malandragem= 40, justica= 60, castigo=  0, perdao=  0, pontos= 33335)
# Estrategia(malandragem= 30, justica= 90, castigo=  0, perdao=  0, pontos= 33311)
# Estrategia(malandragem= 40, justica= 90, castigo=  0, perdao=  0, pontos= 33309)
# Estrategia(malandragem= 40, justica= 40, castigo=  0, perdao=  0, pontos= 33254)
# Estrategia(malandragem= 30, justica= 80, castigo=  0, perdao=  0, pontos= 33175)
# Estrategia(malandragem= 40, justica= 50, castigo=  0, perdao=  0, pontos= 33149)
# Estrategia(malandragem= 50, justica= 10, castigo=  0, perdao=  0, pontos= 33057)
# Estrategia(malandragem= 50, justica=  0, castigo=  0, perdao=  0, pontos= 32872)
# Estrategia(malandragem= 30, justica= 60, castigo=  0, perdao=  0, pontos= 32859)
# Estrategia(malandragem= 40, justica= 20, castigo=  0, perdao=  0, pontos= 32782)
# Estrategia(malandragem= 40, justica= 30, castigo=  0, perdao=  0, pontos= 32732)
# Estrategia(malandragem= 20, justica= 90, castigo=  0, perdao=  0, pontos= 32612)
# Estrategia(malandragem= 30, justica= 70, castigo=  0, perdao=  0, pontos= 32582)
# Estrategia(malandragem= 30, justica= 50, castigo=  0, perdao=  0, pontos= 32567)
# Estrategia(malandragem= 40, justica=  0, castigo=  0, perdao=  0, pontos= 32506)
# Estrategia(malandragem= 40, justica= 10, castigo=  0, perdao=  0, pontos= 32503)
# Estrategia(malandragem= 30, justica= 40, castigo=  0, perdao=  0, pontos= 32498)
# Estrategia(malandragem= 20, justica= 80, castigo=  0, perdao=  0, pontos= 32477)
# Estrategia(malandragem= 30, justica= 30, castigo=  0, perdao=  0, pontos= 32433)
# Estrategia(malandragem= 10, justica= 90, castigo=  0, perdao=  0, pontos= 32327)
# Estrategia(malandragem= 30, justica= 20, castigo=  0, perdao=  0, pontos= 32216)
# Estrategia(malandragem= 20, justica= 70, castigo=  0, perdao=  0, pontos= 32079)
# Estrategia(malandragem= 20, justica= 50, castigo=  0, perdao=  0, pontos= 32036)
# Estrategia(malandragem= 20, justica= 60, castigo=  0, perdao=  0, pontos= 31979)
# Estrategia(malandragem= 10, justica= 80, castigo=  0, perdao=  0, pontos= 31917)
# Estrategia(malandragem= 30, justica=  0, castigo=  0, perdao=  0, pontos= 31893)
# Estrategia(malandragem= 10, justica= 70, castigo=  0, perdao=  0, pontos= 31817)
# Estrategia(malandragem= 10, justica= 60, castigo=  0, perdao=  0, pontos= 31786)
# Estrategia(malandragem= 30, justica= 10, castigo=  0, perdao=  0, pontos= 31715)
# Estrategia(malandragem= 20, justica= 40, castigo=  0, perdao=  0, pontos= 31698)
# Estrategia(malandragem= 20, justica= 30, castigo=  0, perdao=  0, pontos= 31654)
# Estrategia(malandragem=  0, justica= 90, castigo=  0, perdao=  0, pontos= 31516)
# Estrategia(malandragem= 20, justica= 20, castigo=  0, perdao=  0, pontos= 31510)
# Estrategia(malandragem=  0, justica= 80, castigo=  0, perdao=  0, pontos= 31319)
# Estrategia(malandragem= 20, justica= 10, castigo=  0, perdao=  0, pontos= 31229)
# Estrategia(malandragem=  0, justica= 70, castigo=  0, perdao=  0, pontos= 31174)
# Estrategia(malandragem= 10, justica= 50, castigo=  0, perdao=  0, pontos= 31145)
# Estrategia(malandragem= 10, justica= 40, castigo=  0, perdao=  0, pontos= 30998)
# Estrategia(malandragem=  0, justica= 60, castigo=  0, perdao=  0, pontos= 30850)
# Estrategia(malandragem= 20, justica=  0, castigo=  0, perdao=  0, pontos= 30793)
# Estrategia(malandragem= 10, justica= 30, castigo=  0, perdao=  0, pontos= 30694)
# Estrategia(malandragem= 10, justica= 20, castigo=  0, perdao=  0, pontos= 30622)
# Estrategia(malandragem=  0, justica= 50, castigo=  0, perdao=  0, pontos= 30459)
# Estrategia(malandragem=  0, justica= 40, castigo=  0, perdao=  0, pontos= 30041)
# Estrategia(malandragem= 10, justica= 10, castigo=  0, perdao=  0, pontos= 29923)
# Estrategia(malandragem= 10, justica=  0, castigo=  0, perdao=  0, pontos= 29757)
# Estrategia(malandragem=  0, justica= 30, castigo=  0, perdao=  0, pontos= 29618)
# Estrategia(malandragem=  0, justica= 20, castigo=  0, perdao=  0, pontos= 29318)
# Estrategia(malandragem=  0, justica=  0, castigo=  0, perdao=  0, pontos= 28920)
# Estrategia(malandragem=  0, justica= 10, castigo=  0, perdao=  0, pontos= 28801)

# %%
df = pd.DataFrame([asdict(r) for r in resultado])
df.head()
# Out:
#    malandragem  justica  castigo  perdao  pontos
# 0           50        0        0       0    7491
# 1           50        0        0       0    7475
# 2           50        0        0       0    7446
# 3           50        0        0       0    7436
# 4           50        0        0       0    7320

# %%
opts = dict(width=500, height=400, colorbar=True, cmap='coolwarm')
hv.HeatMap(df, kdims=['malandragem', 'justica'], vdims=['pontos']).opts(**opts)
# Out:
# :HeatMap   [malandragem,justica]   (pontos)

# %%
Justiceira = Estrategia(malandragem=0, justica=100)
Trapaceira = Estrategia(malandragem=50, justica=0)
CidadaDeBem = Estrategia(malandragem=50, justica=50)

e = [
    Estrategia(malandragem=m, justica=j)
    for m in range(0, 101, 20)
    for j in range(0, 101, 20)
] + Justiceira * 30

resultado = arena(rodadas=200, estrategias=e)
for i in resultado: print(i);
# Out:
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 30897)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 30872)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 30872)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 30849)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 30840)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 30810)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 30805)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 30800)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 30800)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 30797)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 30794)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 30785)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 30784)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 30781)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 30780)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 30760)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 30752)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 30748)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 30748)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 30724)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 30723)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 30711)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 30709)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 30705)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 30683)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 30680)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 30677)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 30673)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 30667)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 30657)
# Estrategia(malandragem=  0, justica= 80, castigo=  0, perdao=  0, pontos= 30598)
# Estrategia(malandragem=  0, justica=100, castigo=  0, perdao=  0, pontos= 30584)
# Estrategia(malandragem=  0, justica= 60, castigo=  0, perdao=  0, pontos= 29963)
# Estrategia(malandragem=  0, justica= 40, castigo=  0, perdao=  0, pontos= 29397)
# Estrategia(malandragem=  0, justica= 20, castigo=  0, perdao=  0, pontos= 28782)
# Estrategia(malandragem=  0, justica=  0, castigo=  0, perdao=  0, pontos= 28161)
# Estrategia(malandragem= 20, justica= 20, castigo=  0, perdao=  0, pontos= 28132)
# Estrategia(malandragem= 20, justica=  0, castigo=  0, perdao=  0, pontos= 27995)
# Estrategia(malandragem= 20, justica= 40, castigo=  0, perdao=  0, pontos= 27792)
# Estrategia(malandragem= 20, justica= 60, castigo=  0, perdao=  0, pontos= 27314)
# Estrategia(malandragem= 40, justica= 20, castigo=  0, perdao=  0, pontos= 26723)
# Estrategia(malandragem= 40, justica=  0, castigo=  0, perdao=  0, pontos= 26700)
# Estrategia(malandragem= 40, justica= 40, castigo=  0, perdao=  0, pontos= 25977)
# Estrategia(malandragem= 20, justica= 80, castigo=  0, perdao=  0, pontos= 25908)
# Estrategia(malandragem= 60, justica=  0, castigo=  0, perdao=  0, pontos= 25324)
# Estrategia(malandragem= 40, justica= 60, castigo=  0, perdao=  0, pontos= 25148)
# Estrategia(malandragem= 60, justica= 20, castigo=  0, perdao=  0, pontos= 24585)
# Estrategia(malandragem= 60, justica= 40, castigo=  0, perdao=  0, pontos= 23970)
# Estrategia(malandragem= 40, justica= 80, castigo=  0, perdao=  0, pontos= 23362)
# Estrategia(malandragem= 60, justica= 60, castigo=  0, perdao=  0, pontos= 23150)
# Estrategia(malandragem= 80, justica=  0, castigo=  0, perdao=  0, pontos= 23049)
# Estrategia(malandragem= 80, justica= 20, castigo=  0, perdao=  0, pontos= 22527)
# Estrategia(malandragem= 80, justica= 40, castigo=  0, perdao=  0, pontos= 22258)
# Estrategia(malandragem= 60, justica= 80, castigo=  0, perdao=  0, pontos= 21731)
# Estrategia(malandragem= 80, justica= 60, castigo=  0, perdao=  0, pontos= 21464)
# Estrategia(malandragem= 80, justica= 80, castigo=  0, perdao=  0, pontos= 20801)
# Estrategia(malandragem=100, justica= 40, castigo=  0, perdao=  0, pontos= 20544)
# Estrategia(malandragem=100, justica=100, castigo=  0, perdao=  0, pontos= 20484)
# Estrategia(malandragem=100, justica=  0, castigo=  0, perdao=  0, pontos= 20408)
# Estrategia(malandragem=100, justica= 80, castigo=  0, perdao=  0, pontos= 20400)
# Estrategia(malandragem=100, justica= 60, castigo=  0, perdao=  0, pontos= 20340)
# Estrategia(malandragem=100, justica= 20, castigo=  0, perdao=  0, pontos= 20296)
# Estrategia(malandragem= 80, justica=100, castigo=  0, perdao=  0, pontos= 20172)
# Estrategia(malandragem= 20, justica=100, castigo=  0, perdao=  0, pontos= 19848)
# Estrategia(malandragem= 60, justica=100, castigo=  0, perdao=  0, pontos= 19812)
# Estrategia(malandragem= 40, justica=100, castigo=  0, perdao=  0, pontos= 19752)

# %%
df = pd.DataFrame([asdict(r) for r in resultado])
df2 = df.groupby(['malandragem', 'justica'])['pontos'].mean().reset_index()

# %%
opts = dict(width=500, height=400, colorbar=True, cmap='coolwarm')
hv.HeatMap(df2, kdims=['malandragem', 'justica'], vdims=['pontos']).opts(**opts)
# Out:
# :HeatMap   [malandragem,justica]   (pontos)
